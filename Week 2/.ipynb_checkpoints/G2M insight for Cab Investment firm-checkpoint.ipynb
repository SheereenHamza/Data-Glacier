# %% [markdown]
# <hr />
#
# # G2M insight for Cab Investment firm
# <hr />
# <hr />
# <br />

# %% [markdown]
# ## Problem Statement
# <hr />
#
# XYZ is a private firm in US. Due to remarkable growth in the Cab Industry in last few years and multiple key players in the market, it is planning for an investment in Cab industry and as per their Go-to-Market(G2M) strategy they want to understand the market before taking final decision.
#
# You have been provided with multiple data sets that contains information on 2 cab companies. Each file (data set) provided represents different aspects of the customer profile. XYZ is interested in using your actionable insights to help them identify the right company to make their investment.
#
# <br />
# <br />

# %% [markdown]
# ## Data Understanding
# <hr />
#
# You have been provided 4 individual data sets. Time period of data is from 31/01/2016 to 31/12/2018.
#
# Below are the list of datasets which are provided for the analysis:
#
# <ol>
#     <li> <b> Cab_Data.csv : </b> this file includes details of transaction for 2 cab companies </li>
#     <li> <b> Customer_ID.csv : </b> this is a mapping table that contains a unique identifier which links the customer’s demographic details </li>
#     <li> <b> Transaction_ID.csv : </b> this is a mapping table that contains transaction to customer mapping and payment mode </li>
#     <li> <b> City.csv : </b> this file contains list of US cities, their population and number of cab users </li>
# </ol>
#
# <br />

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
# !pip install fuzzywuzzy
# Out:
# Requirement already satisfied: fuzzywuzzy in c:\users\kvham\anaconda3\lib\site-packages (0.18.0)

# %%
import fuzzywuzzy
from fuzzywuzzy import process
import chardet

# %% [markdown]
# Let us import the datasets

# %%
cab_df = pd.read_csv('DataSets/Cab_Data.csv') # cab details
cust_df = pd.read_csv('DataSets/Customer_ID.csv') # customer details
trans_df = pd.read_csv('DataSets/Transaction_ID.csv') # transaction details
city_df = pd.read_csv('DataSets/City.csv') # city details

# %% [markdown]
# Let us analyse the 4 datasets to find the following:
# 1. Shape
# 2. Columns and their datatypes
# 3. Head / snapshot of the dataset
# 4. Unique info
# 5. Other statistics of numerical columns

# %% [markdown]
# ### cab_df

# %%
cab_df.shape
# Out:
# (359392, 7)

# %%
cab_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359392 entries, 0 to 359391
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  359392 non-null  int64
#  1   Date of Travel  359392 non-null  int64
#  2   Company         359392 non-null  object
#  3   City            359392 non-null  object
#  4   KM Travelled    359392 non-null  float64
#  5   Price Charged   359392 non-null  float64
#  6   Cost of Trip    359392 non-null  float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 19.2+ MB

# %%
cab_df.describe()
# Out:
#        Transaction ID  Date of Travel   KM Travelled  Price Charged  \
# count    3.593920e+05   359392.000000  359392.000000  359392.000000
# mean     1.022076e+07    42964.067998      22.567254     423.443311
# std      1.268058e+05      307.467197      12.233526     274.378911
# min      1.000001e+07    42371.000000       1.900000      15.600000
# 25%      1.011081e+07    42697.000000      12.000000     206.437500
# 50%      1.022104e+07    42988.000000      22.440000     386.360000
# 75%      1.033094e+07    43232.000000      32.960000     583.660000
# max      1.044011e+07    43465.000000      48.000000    2048.030000
#
#         Cost of Trip
# count  359392.000000
# mean      286.190113
# std       157.993661
# min        19.000000
# 25%       151.200000
# 50%       282.480000
# 75%       413.683200
# max       691.200000

# %%
cab_df.head()
# Out:
#    Transaction ID  Date of Travel   Company        City  KM Travelled  \
# 0        10000011           42377  Pink Cab  ATLANTA GA         30.45
# 1        10000012           42375  Pink Cab  ATLANTA GA         28.62
# 2        10000013           42371  Pink Cab  ATLANTA GA          9.04
# 3        10000014           42376  Pink Cab  ATLANTA GA         33.17
# 4        10000015           42372  Pink Cab  ATLANTA GA          8.73
#
#    Price Charged  Cost of Trip
# 0         370.95       313.635
# 1         358.52       334.854
# 2         125.20        97.632
# 3         377.40       351.602
# 4         114.62        97.776

# %%
print(cab_df.Company.value_counts(), '\n')
print(cab_df.City.value_counts(), '\n')
print(cab_df['Date of Travel'].value_counts())
# Out:
# Yellow Cab    274681
# Pink Cab       84711
# Name: Company, dtype: int64
#
# NEW YORK NY       99885
# CHICAGO IL        56625
# LOS ANGELES CA    48033
# WASHINGTON DC     43737
# BOSTON MA         29692
# SAN DIEGO CA      20488
# SILICON VALLEY     8519
# SEATTLE WA         7997
# ATLANTA GA         7557
# DALLAS TX          7017
# MIAMI FL           6454
# AUSTIN TX          4896
# ORANGE COUNTY      3982
# DENVER CO          3825
# NASHVILLE TN       3010
# SACRAMENTO CA      2367
# PHOENIX AZ         2064
# TUCSON AZ          1931
# PITTSBURGH PA      1313
# Name: City, dtype: int64
#
# 43105    2022
# 43084    1123
# 43077    1100
# 43449    1086
# 43063    1085
#          ...
# 42388      88
# 42381      86
# 42380      85
# 42374      47
# 42373      25
# Name: Date of Travel, Length: 1095, dtype: int64

# %% [markdown]
# <br />
#
# ### cust_df

# %%
cust_df.shape
# Out:
# (49171, 4)

# %%
cust_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49171 entries, 0 to 49170
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer ID         49171 non-null  int64
#  1   Gender              49171 non-null  object
#  2   Age                 49171 non-null  int64
#  3   Income (USD/Month)  49171 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %%
cust_df.describe()
# Out:
#         Customer ID           Age  Income (USD/Month)
# count  49171.000000  49171.000000        49171.000000
# mean   28398.252283     35.363121        15015.631856
# std    17714.137333     12.599066         8002.208253
# min        1.000000     18.000000         2000.000000
# 25%    12654.500000     25.000000         8289.500000
# 50%    27631.000000     33.000000        14656.000000
# 75%    43284.500000     42.000000        21035.000000
# max    60000.000000     65.000000        35000.000000

# %%
cust_df.head()
# Out:
#    Customer ID Gender  Age  Income (USD/Month)
# 0        29290   Male   28               10813
# 1        27703   Male   27                9237
# 2        28712   Male   53               11242
# 3        28020   Male   23               23327
# 4        27182   Male   33                8536

# %% [markdown]
# <br />
#
# ### trans_df

# %%
trans_df.shape
# Out:
# (440098, 3)

# %%
trans_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440098 entries, 0 to 440097
# Data columns (total 3 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  440098 non-null  int64
#  1   Customer ID     440098 non-null  int64
#  2   Payment_Mode    440098 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 10.1+ MB

# %%
trans_df.describe()
# Out:
#        Transaction ID    Customer ID
# count    4.400980e+05  440098.000000
# mean     1.022006e+07   23619.513120
# std      1.270455e+05   21195.549816
# min      1.000001e+07       1.000000
# 25%      1.011004e+07    3530.000000
# 50%      1.022006e+07   15168.000000
# 75%      1.033008e+07   43884.000000
# max      1.044011e+07   60000.000000

# %%
trans_df.head()
# Out:
#    Transaction ID  Customer ID Payment_Mode
# 0        10000011        29290         Card
# 1        10000012        27703         Card
# 2        10000013        28712         Cash
# 3        10000014        28020         Cash
# 4        10000015        27182         Card

# %%
trans_df.Payment_Mode.value_counts()
# Out:
# Card    263991
# Cash    176107
# Name: Payment_Mode, dtype: int64

# %% [markdown]
# <br />
#
# ### city_df

# %%
city_df.shape
# Out:
# (20, 3)

# %%
city_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        20 non-null     object
#  1   Population  20 non-null     object
#  2   Users       20 non-null     object
# dtypes: object(3)
# memory usage: 608.0+ bytes

# %%
city_df.describe()
# Out:
#                City Population     Users
# count            20         20        20
# unique           20         20        20
# top     NEW YORK NY   698,371    12,994
# freq              1          1         1

# %%
city_df.head()
# Out:
#              City   Population      Users
# 0     NEW YORK NY   8,405,837    302,149
# 1      CHICAGO IL   1,955,130    164,468
# 2  LOS ANGELES CA   1,595,037    144,132
# 3        MIAMI FL   1,339,155     17,675
# 4  SILICON VALLEY   1,177,609     27,247

# %%
city_df.City.value_counts()
# Out:
# NEW YORK NY         1
# SEATTLE WA          1
# TUCSON AZ           1
# LOS ANGELES CA      1
# BOSTON MA           1
# SAN DIEGO CA        1
# SACRAMENTO CA       1
# ATLANTA GA          1
# PITTSBURGH PA       1
# PHOENIX AZ          1
# NASHVILLE TN        1
# CHICAGO IL          1
# AUSTIN TX           1
# ORANGE COUNTY       1
# SILICON VALLEY      1
# DENVER CO           1
# SAN FRANCISCO CA    1
# WASHINGTON DC       1
# DALLAS TX           1
# MIAMI FL            1
# Name: City, dtype: int64

# %% [markdown]
# <br />
# <br />

# %% [markdown]
# ## Data Cleaning
# <hr />
#
# <ol>
#     <li> Check for null values </li>
#     <li> Check for duplicate entries </li>
#     <li> Check names of columns </li>
#     <li> Check datatype and values in columns </li>
#     <li> Check unique values in columns </li>
#     <li> Merge dataframes and drop columns not necessary for analysis </li>
#     <li> Derive features, if necessary </li>
#     <li> Check for outliers </li>
#     <li> Sanity checks </li>
# </ol>
#
# <br />
# <br />

# %% [markdown]
# <br />
#
# ### 1. Check for null values
# <hr />

# %%
print('Percentage of null values in:')
print('   cab_df: {}%\n   cust_df: {}%\n   trans_df: {}%\n   city_df: {}%'.format(
    round(cab_df.isnull().sum().sum() / cab_df.shape[0] * 100, 2),
    round(cust_df.isnull().sum().sum() / cust_df.shape[0] * 100, 2),
    round(trans_df.isnull().sum().sum() / trans_df.shape[0] * 100, 2),
    round(city_df.isnull().sum().sum() / city_df.shape[0] * 100, 2)
))
# Out:
# Percentage of null values in:
#    cab_df: 0.0%
#    cust_df: 0.0%
#    trans_df: 0.0%
#    city_df: 0.0%

# %% [markdown]
# <br />
# <br />
#
# ### 2. Check for duplicate entries
# <hr />

# %%
print('No of duplicate entries in: ')
print('   cab_df: {}\n   cust_df: {}\n   trans_df: {}\n   city_df:{}'.format(
    cab_df.duplicated().sum(), cust_df.duplicated().sum(), trans_df.duplicated().sum(), city_df.duplicated().sum()
))
# Out:
# No of duplicate entries in:
#    cab_df: 0
#    cust_df: 0
#    trans_df: 0
#    city_df:0

# %% [markdown]
# <br />
# <br />
#
# ### 3. Check names of the columns
# <hr/>

# %%
dataframes = {'cab_df': cab_df, 'cust_df': cust_df, 'trans_df': trans_df, 'city_df': city_df}

for df_name, df in dataframes.items():
    print(df_name, '\n', '='*25, '\n')
    print(df.info(), '\n')
# Out:
# cab_df
#  =========================
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359392 entries, 0 to 359391
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  359392 non-null  int64
#  1   Date of Travel  359392 non-null  int64
#  2   Company         359392 non-null  object
#  3   City            359392 non-null  object
#  4   KM Travelled    359392 non-null  float64
#  5   Price Charged   359392 non-null  float64
#  6   Cost of Trip    359392 non-null  float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 19.2+ MB
# None
#
# cust_df
#  =========================
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49171 entries, 0 to 49170
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer ID         49171 non-null  int64
#  1   Gender              49171 non-null  object
#  2   Age                 49171 non-null  int64
#  3   Income (USD/Month)  49171 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB
# None
#
# trans_df
#  =========================
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440098 entries, 0 to 440097
# Data columns (total 3 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  440098 non-null  int64
#  1   Customer ID     440098 non-null  int64
#  2   Payment_Mode    440098 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 10.1+ MB
# None
#
# city_df
#  =========================
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        20 non-null     object
#  1   Population  20 non-null     object
#  2   Users       20 non-null     object
# dtypes: object(3)
# memory usage: 608.0+ bytes
# None

# %% [markdown]
# Let us make the column names follow <i>snake_case</i>, for ease of use.
#
# Let us also change <b>Income (USD/Month)</b> of cust_df to <b>income_usd_per_month</b>.

# %%
for df_name, df in dataframes.items():
    if df_name == 'cust_df':
        df.rename(columns={'Income (USD/Month)':'income_usd_per_month'}, inplace=True)
    cols = ['_'.join(col.lower().split()) for col in df.columns]
    df.columns = cols
    # check if the change was made
    print(df_name, '\n', '='*10, '\n')
    print(df.columns, '\n')
# Out:
# cab_df
#  ==========
#
# Index(['transaction_id', 'date_of_travel', 'company', 'city', 'km_travelled',
#        'price_charged', 'cost_of_trip'],
#       dtype='object')
#
# cust_df
#  ==========
#
# Index(['customer_id', 'gender', 'age', 'income_usd_per_month'], dtype='object')
#
# trans_df
#  ==========
#
# Index(['transaction_id', 'customer_id', 'payment_mode'], dtype='object')
#
# city_df
#  ==========
#
# Index(['city', 'population', 'users'], dtype='object')

# %% [markdown]
# <br />
# <br />
#
# ### 4. Check datatype of columns
# <hr />

# %%
for df_name, df in dataframes.items():
    print(df_name, '\n', '='*25, '\n')
    print(df.info(), '\n')
    print(df.head(3),'\n', '-'*100, '\n')
# Out:
# cab_df
#  =========================
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359392 entries, 0 to 359391
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   transaction_id  359392 non-null  int64
#  1   date_of_travel  359392 non-null  int64
#  2   company         359392 non-null  object
#  3   city            359392 non-null  object
#  4   km_travelled    359392 non-null  float64
#  5   price_charged   359392 non-null  float64
#  6   cost_of_trip    359392 non-null  float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 19.2+ MB
# None
#
#    transaction_id  date_of_travel   company        city  km_travelled  \
# 0        10000011           42377  Pink Cab  ATLANTA GA         30.45
# 1        10000012           42375  Pink Cab  ATLANTA GA         28.62
# 2        10000013           42371  Pink Cab  ATLANTA GA          9.04
#
#    price_charged  cost_of_trip
# 0         370.95       313.635
# 1         358.52       334.854
# 2         125.20        97.632
#  ----------------------------------------------------------------------------------------------------
#
# cust_df
#  =========================
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49171 entries, 0 to 49170
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   customer_id           49171 non-null  int64
#  1   gender                49171 non-null  object
#  2   age                   49171 non-null  int64
#  3   income_usd_per_month  49171 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB
# None
#
#    customer_id gender  age  income_usd_per_month
# 0        29290   Male   28                 10813
# 1        27703   Male   27                  9237
# 2        28712   Male   53                 11242
#  ----------------------------------------------------------------------------------------------------
#
# trans_df
#  =========================
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440098 entries, 0 to 440097
# Data columns (total 3 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   transaction_id  440098 non-null  int64
#  1   customer_id     440098 non-null  int64
#  2   payment_mode    440098 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 10.1+ MB
# None
#
#    transaction_id  customer_id payment_mode
# 0        10000011        29290         Card
# 1        10000012        27703         Card
# 2        10000013        28712         Cash
#  ----------------------------------------------------------------------------------------------------
#
# city_df
#  =========================
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   city        20 non-null     object
#  1   population  20 non-null     object
#  2   users       20 non-null     object
# dtypes: object(3)
# memory usage: 608.0+ bytes
# None
#
#              city   population      users
# 0     NEW YORK NY   8,405,837    302,149
# 1      CHICAGO IL   1,955,130    164,468
# 2  LOS ANGELES CA   1,595,037    144,132
#  ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ### <i>Observations</i>
# ------------------------------
# 1. cab_df: The <b>date_of_travel</b> column is of type </i>integer</i>. It should be <i>datetime</i>. Moreover, it has erronous values
# 2. city_df: The <b>population</b> and <b>users</b> columns are of type <i>object</i>. It should be <i>integer</i>
# </b>

# %%
# check unique values in population and users column in city_df
print(city_df.population.value_counts())
print("\n\n", city_df.users.value_counts())
# Out:
#  698,371       1
#  754,233       1
#  1,030,185     1
#  545,776       1
#  327,225       1
#  8,405,837     1
#  671,238       1
#  942,908       1
#  1,177,609     1
#  629,591       1
#  814,885       1
#  1,595,037     1
#  542,085       1
#  631,442       1
#  248,968       1
#  959,307       1
#  1,339,155     1
#  943,999       1
#  1,955,130     1
#  418,859       1
# Name: population, dtype: int64
#
#
#   12,994      1
#  22,157      1
#  12,421      1
#  144,132     1
#  69,995      1
#  3,643       1
#  5,712       1
#  14,978      1
#  9,270       1
#  7,044       1
#  6,133       1
#  80,021      1
#  27,247      1
#  213,609     1
#  127,001     1
#  25,063      1
#  17,675      1
#  24,701      1
#  302,149     1
#  164,468     1
# Name: users, dtype: int64

# %% [markdown]
# We can convert both these columns from type <i>object</i> to type <i>int</i> by removing the commas.

# %%
# convert population and users to type int
print("Before conversion: ", city_df.info(), "\n")
print(city_df.head(), "\n\n\n")

city_df.population = city_df.population.apply(lambda pop: int(pop.strip().replace(',','')))
city_df.users = city_df.users.apply(lambda us: int(us.strip().replace(',','')))

print("After conversion: ", city_df.info(), "\n")
print(city_df.head(), "\n\n\n")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   city        20 non-null     object
#  1   population  20 non-null     object
#  2   users       20 non-null     object
# dtypes: object(3)
# memory usage: 608.0+ bytes
# Before conversion:  None
#
#              city   population      users
# 0     NEW YORK NY   8,405,837    302,149
# 1      CHICAGO IL   1,955,130    164,468
# 2  LOS ANGELES CA   1,595,037    144,132
# 3        MIAMI FL   1,339,155     17,675
# 4  SILICON VALLEY   1,177,609     27,247
#
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   city        20 non-null     object
#  1   population  20 non-null     int64
#  2   users       20 non-null     int64
# dtypes: int64(2), object(1)
# memory usage: 608.0+ bytes
# After conversion:  None
#
#              city  population   users
# 0     NEW YORK NY     8405837  302149
# 1      CHICAGO IL     1955130  164468
# 2  LOS ANGELES CA     1595037  144132
# 3        MIAMI FL     1339155   17675
# 4  SILICON VALLEY     1177609   27247

# %% [markdown]
# <br />
# <br />
#
# ### 4. Check unique values in columns
# <hr />

# %%
for df_name, df in dataframes.items():
    print(df_name, "   ", df.shape)
    print('='*25, '\n')
    for col in df.columns:
        print(col)
        print('-'*15)
        print('No of unique values: ', df[col].nunique())
        print('Percentage of unique values: ', round(df[col].nunique() / df.shape[0] * 100, 2), '%')
        print(df[col].value_counts(), '\n')
    print('\n\n')
# Out:
# cab_df     (359392, 7)
# =========================
#
# transaction_id
# ---------------
# No of unique values:  359392
# Percentage of unique values:  100.0 %
# 10000403    1
# 10249510    1
# 10235183    1
# 10233134    1
# 10239277    1
#            ..
# 10273741    1
# 10286027    1
# 10288074    1
# 10281929    1
# 10000365    1
# Name: transaction_id, Length: 359392, dtype: int64
#
# date_of_travel
# ---------------
# No of unique values:  1095
# Percentage of unique values:  0.3 %
# 43105    2022
# 43084    1123
# 43077    1100
# 43449    1086
# 43063    1085
#          ...
# 42388      88
# 42381      86
# 42380      85
# 42374      47
# 42373      25
# Name: date_of_travel, Length: 1095, dtype: int64
#
# company
# ---------------
# No of unique values:  2
# Percentage of unique values:  0.0 %
# Yellow Cab    274681
# Pink Cab       84711
# Name: company, dtype: int64
#
# city
# ---------------
# No of unique values:  19
# Percentage of unique values:  0.01 %
# NEW YORK NY       99885
# CHICAGO IL        56625
# LOS ANGELES CA    48033
# WASHINGTON DC     43737
# BOSTON MA         29692
# SAN DIEGO CA      20488
# SILICON VALLEY     8519
# SEATTLE WA         7997
# ATLANTA GA         7557
# DALLAS TX          7017
# MIAMI FL           6454
# AUSTIN TX          4896
# ORANGE COUNTY      3982
# DENVER CO          3825
# NASHVILLE TN       3010
# SACRAMENTO CA      2367
# PHOENIX AZ         2064
# TUCSON AZ          1931
# PITTSBURGH PA      1313
# Name: city, dtype: int64
#
# km_travelled
# ---------------
# No of unique values:  874
# Percentage of unique values:  0.24 %
# 33.60    1536
# 24.00    1080
# 22.80    1075
# 35.70    1069
# 16.80    1065
#          ...
# 29.58     308
# 12.24     306
# 3.51      301
# 39.39     300
# 21.84     293
# Name: km_travelled, Length: 874, dtype: int64
#
# price_charged
# ---------------
# No of unique values:  99176
# Percentage of unique values:  27.6 %
# 298.32     18
# 191.27     18
# 181.59     17
# 216.37     17
# 198.80     17
#            ..
# 817.70      1
# 945.30      1
# 494.12      1
# 878.67      1
# 1251.57     1
# Name: price_charged, Length: 99176, dtype: int64
#
# cost_of_trip
# ---------------
# No of unique values:  16291
# Percentage of unique values:  4.53 %
# 362.880    186
# 479.808    184
# 471.744    180
# 205.632    178
# 336.960    166
#           ...
# 251.750      1
# 103.887      1
# 173.349      1
# 137.800      1
# 206.682      1
# Name: cost_of_trip, Length: 16291, dtype: int64
#
#
#
#
# cust_df     (49171, 4)
# =========================
#
# customer_id
# ---------------
# No of unique values:  49171
# Percentage of unique values:  100.0 %
# 2049     1
# 20607    1
# 37639    1
# 58121    1
# 51980    1
#         ..
# 28039    1
# 5512     1
# 7561     1
# 1418     1
# 2047     1
# Name: customer_id, Length: 49171, dtype: int64
#
# gender
# ---------------
# No of unique values:  2
# Percentage of unique values:  0.0 %
# Male      26562
# Female    22609
# Name: gender, dtype: int64
#
# age
# ---------------
# No of unique values:  48
# Percentage of unique values:  0.1 %
# 20    1641
# 34    1629
# 39    1624
# 23    1615
# 25    1597
# 22    1596
# 28    1588
# 32    1585
# 26    1577
# 37    1575
# 30    1573
# 27    1571
# 40    1561
# 19    1561
# 21    1554
# 18    1551
# 31    1549
# 24    1547
# 36    1534
# 38    1512
# 29    1511
# 35    1503
# 33    1495
# 61     580
# 59     552
# 45     551
# 46     540
# 49     539
# 52     539
# 47     539
# 50     538
# 58     536
# 64     536
# 48     533
# 43     532
# 42     526
# 51     525
# 41     523
# 56     521
# 63     512
# 53     510
# 54     506
# 55     504
# 60     501
# 57     498
# 62     497
# 44     492
# 65     492
# Name: age, dtype: int64
#
# income_usd_per_month
# ---------------
# No of unique values:  23341
# Percentage of unique values:  47.47 %
# 8497     11
# 16512    10
# 8756     10
# 21804     9
# 8580      9
#          ..
# 26056     1
# 25438     1
# 27487     1
# 33634     1
# 12074     1
# Name: income_usd_per_month, Length: 23341, dtype: int64
#
#
#
#
# trans_df     (440098, 3)
# =========================
#
# transaction_id
# ---------------
# No of unique values:  440098
# Percentage of unique values:  100.0 %
# 10000659    1
# 10031735    1
# 10027637    1
# 10029684    1
# 10039923    1
#            ..
# 10003902    1
# 10010045    1
# 10007996    1
# 10001849    1
# 10000109    1
# Name: transaction_id, Length: 440098, dtype: int64
#
# customer_id
# ---------------
# No of unique values:  49171
# Percentage of unique values:  11.17 %
# 494      54
# 2939     53
# 2766     51
# 1070     51
# 2539     50
#          ..
# 14539     1
# 54040     1
# 26470     1
# 32613     1
# 23303     1
# Name: customer_id, Length: 49171, dtype: int64
#
# payment_mode
# ---------------
# No of unique values:  2
# Percentage of unique values:  0.0 %
# Card    263991
# Cash    176107
# Name: payment_mode, dtype: int64
#
#
#
#
# city_df     (20, 3)
# =========================
#
# city
# ---------------
# No of unique values:  20
# Percentage of unique values:  100.0 %
# NEW YORK NY         1
# SEATTLE WA          1
# TUCSON AZ           1
# LOS ANGELES CA      1
# BOSTON MA           1
# SAN DIEGO CA        1
# SACRAMENTO CA       1
# ATLANTA GA          1
# PITTSBURGH PA       1
# PHOENIX AZ          1
# NASHVILLE TN        1
# CHICAGO IL          1
# AUSTIN TX           1
# ORANGE COUNTY       1
# SILICON VALLEY      1
# DENVER CO           1
# SAN FRANCISCO CA    1
# WASHINGTON DC       1
# DALLAS TX           1
# MIAMI FL            1
# Name: city, dtype: int64
#
# population
# ---------------
# No of unique values:  20
# Percentage of unique values:  100.0 %
# 542085     1
# 698371     1
# 1595037    1
# 942908     1
# 1955130    1
# 754233     1
# 327225     1
# 629591     1
# 418859     1
# 1339155    1
# 1030185    1
# 545776     1
# 8405837    1
# 631442     1
# 959307     1
# 1177609    1
# 248968     1
# 671238     1
# 814885     1
# 943999     1
# Name: population, dtype: int64
#
# users
# ---------------
# No of unique values:  20
# Percentage of unique values:  100.0 %
# 12994     1
# 144132    1
# 3643      1
# 127001    1
# 69995     1
# 9270      1
# 6133      1
# 164468    1
# 7044      1
# 80021     1
# 5712      1
# 27247     1
# 22157     1
# 12421     1
# 17675     1
# 213609    1
# 25063     1
# 14978     1
# 302149    1
# 24701     1
# Name: users, dtype: int64

# %% [markdown]
# ### <i>Observations</i>
# ------------------------------
# 1. ### cab_df:
#    ----------
#     - <b>transaction_id</b> has 100% unique values. We can drop this column as it will add no value to our analysis.
#     - <b>date_of_travel</b> has date stored as excel serial date. Let us convert it to datetime.
#     - <b>company</b> has on only 2 unique values: Yellow cab and Pink cab. This column segments the whole data to 2.
#     - <b>city</b> also has considerable amount of unique values, 19.
#     - <b>km_travelled</b> has 0.24% unique values. That is 874 out of the 359392. We can have more unique values by rounding off the floating value to nearest integer.
#     - We can similarly round of values of <b>price_charged</b> and <b>cost_of_trip</b>.
#
#     <br />
#
# 2. ### cust_df
#    ----------
#    - <b>customer_id</b> has 100% unique values. We can drop this column as it will add no value to our analysis.
#    - <b>gender</b> has 2 unique values: Male and Female
#    - <b>age</b> has 0.1% unique values. That is 48 out of the total 49171 values are unique. We can have more unique values by giving in age groups, rather than age just like that.
#    - <b>income_usd_per_month</b> has about 50% unique values. We can have more unique values by rounding of this value.
#
#    <br />
#
# 3. ### trans_df
#    ----------
#    - <b>transaction_id</b> has 100% unique values. We can drop this column as it will add no value to our analysis.
#    - <b>customer_id</b> has all the values in the customer_id column of cust_df.
#    - <b>payment_mode</b> has 2 unique values: Cash and Card
#
#    <br />
#
# 4. ### city_df
#    ----------
#    - All the columns are of significance here.
#
#
# <br />
#
#
# There are some columns that can be dropped. But, we will do the same only after we rectify the errors found in some of them followed by merging all the dataframes into a master dataframe.
#
#
# <br />
# <br />

# %%
# convert date_of_travel to type datetime
import xlrd

print("Before conversion: \n")
print(cab_df.info(), "\n")
print(cab_df.head(), "\n\n\n")

cab_df.date_of_travel = cab_df.date_of_travel.apply(lambda d: xlrd.xldate_as_datetime(d, 0).date())
cab_df.date_of_travel = pd.to_datetime(cab_df.date_of_travel)

print("After conversion: \n")
print(cab_df.info(), "\n")
print(cab_df.head())
# Out:
# Before conversion:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359392 entries, 0 to 359391
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   transaction_id  359392 non-null  int64
#  1   date_of_travel  359392 non-null  int64
#  2   company         359392 non-null  object
#  3   city            359392 non-null  object
#  4   km_travelled    359392 non-null  float64
#  5   price_charged   359392 non-null  float64
#  6   cost_of_trip    359392 non-null  float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 19.2+ MB
# None
#
#    transaction_id  date_of_travel   company        city  km_travelled  \
# 0        10000011           42377  Pink Cab  ATLANTA GA         30.45
# 1        10000012           42375  Pink Cab  ATLANTA GA         28.62
# 2        10000013           42371  Pink Cab  ATLANTA GA          9.04
# 3        10000014           42376  Pink Cab  ATLANTA GA         33.17
# 4        10000015           42372  Pink Cab  ATLANTA GA          8.73
#
#    price_charged  cost_of_trip
# 0         370.95       313.635
# 1         358.52       334.854
# 2         125.20        97.632
# 3         377.40       351.602
# 4         114.62        97.776
#
#
#
# After conversion:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359392 entries, 0 to 359391
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   transaction_id  359392 non-null  int64
#  1   date_of_travel  359392 non-null  datetime64[ns]
#  2   company         359392 non-null  object
#  3   city            359392 non-null  object
#  4   km_travelled    359392 non-null  float64
#  5   price_charged   359392 non-null  float64
#  6   cost_of_trip    359392 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(2)
# memory usage: 19.2+ MB
# None
#
#    transaction_id date_of_travel   company        city  km_travelled  \
# 0        10000011     2016-01-08  Pink Cab  ATLANTA GA         30.45
# 1        10000012     2016-01-06  Pink Cab  ATLANTA GA         28.62
# 2        10000013     2016-01-02  Pink Cab  ATLANTA GA          9.04
# 3        10000014     2016-01-07  Pink Cab  ATLANTA GA         33.17
# 4        10000015     2016-01-03  Pink Cab  ATLANTA GA          8.73
#
#    price_charged  cost_of_trip
# 0         370.95       313.635
# 1         358.52       334.854
# 2         125.20        97.632
# 3         377.40       351.602
# 4         114.62        97.776

# %%
# # round values in km_travelled, price_charged and cost_of_trip
# cols = ['km_travelled', 'price_charged', 'cost_of_trip']
# print("Before rounding values: \n")
# for col in cols:
#         print(col)
#         print('-'*15)
#         print('No of unique values: ', cab_df[col].nunique())
#         print('Percentage of unique values: ', round(cab_df[col].nunique() / cab_df.shape[0] * 100, 2), '%')
#         print(cab_df[col].value_counts(), '\n')
# print("\n\n\n")

# for col in cols:
#     cab_df[col] = cab_df[col].apply(lambda v: round(v))

# print("After rounding values: \n")
# for col in cols:
#         print(col)
#         print('-'*15)
#         print('No of unique values: ', cab_df[col].nunique())
#         print('Percentage of unique values: ', round(cab_df[col].nunique() / cab_df.shape[0] * 100, 2), '%')
#         print(cab_df[col].value_counts(), '\n')
# print("\n\n")

# %% [markdown]
# Let us use fuzzy logic to check for same entries with different spelling etc.. in the <b>city</b> column of <b>city_df</b>.

# %%
cab_df.head()
# Out:
#    transaction_id date_of_travel   company        city  km_travelled  \
# 0        10000011     2016-01-08  Pink Cab  ATLANTA GA         30.45
# 1        10000012     2016-01-06  Pink Cab  ATLANTA GA         28.62
# 2        10000013     2016-01-02  Pink Cab  ATLANTA GA          9.04
# 3        10000014     2016-01-07  Pink Cab  ATLANTA GA         33.17
# 4        10000015     2016-01-03  Pink Cab  ATLANTA GA          8.73
#
#    price_charged  cost_of_trip
# 0         370.95       313.635
# 1         358.52       334.854
# 2         125.20        97.632
# 3         377.40       351.602
# 4         114.62        97.776

# %%
# get the top 5 closest matches to each fo the city names in both cab_df and city_df
print("cab_df")
print("-"*25)
for city in cab_df.city.unique():
    matches = fuzzywuzzy.process.extract(city, cab_df.city.unique(), limit=3, scorer=fuzzywuzzy.fuzz.token_sort_ratio)
    print(city, ":  --->  ", matches)

    
print("\n\ncity_df")
print("-"*25)
for city in city_df.city.unique():
    matches = fuzzywuzzy.process.extract(city, city_df.city.unique(), limit=3, scorer=fuzzywuzzy.fuzz.token_sort_ratio)
    print(city, ":  --->  ", matches)
# Out:
# cab_df
# -------------------------
# ATLANTA GA :  --->   [('ATLANTA GA', 100), ('AUSTIN TX', 42), ('DALLAS TX', 42)]
# AUSTIN TX :  --->   [('AUSTIN TX', 100), ('DALLAS TX', 56), ('NASHVILLE TN', 48)]
# BOSTON MA :  --->   [('BOSTON MA', 100), ('AUSTIN TX', 44), ('SILICON VALLEY', 43)]
# CHICAGO IL :  --->   [('CHICAGO IL', 100), ('SAN DIEGO CA', 45), ('WASHINGTON DC', 43)]
# DALLAS TX :  --->   [('DALLAS TX', 100), ('AUSTIN TX', 56), ('NASHVILLE TN', 48)]
# DENVER CO :  --->   [('DENVER CO', 100), ('SAN DIEGO CA', 38), ('ORANGE COUNTY', 36)]
# LOS ANGELES CA :  --->   [('LOS ANGELES CA', 100), ('SEATTLE WA', 42), ('NEW YORK NY', 40)]
# MIAMI FL :  --->   [('MIAMI FL', 100), ('BOSTON MA', 35), ('ATLANTA GA', 33)]
# NASHVILLE TN :  --->   [('NASHVILLE TN', 100), ('WASHINGTON DC', 48), ('DALLAS TX', 38)]
# NEW YORK NY :  --->   [('NEW YORK NY', 100), ('ORANGE COUNTY', 42), ('LOS ANGELES CA', 40)]
# ORANGE COUNTY :  --->   [('ORANGE COUNTY', 100), ('NEW YORK NY', 42), ('SAN DIEGO CA', 40)]
# PHOENIX AZ :  --->   [('PHOENIX AZ', 100), ('TUCSON AZ', 53), ('SAN DIEGO CA', 36)]
# PITTSBURGH PA :  --->   [('PITTSBURGH PA', 100), ('TUCSON AZ', 36), ('PHOENIX AZ', 35)]
# SACRAMENTO CA :  --->   [('SACRAMENTO CA', 100), ('SAN DIEGO CA', 48), ('WASHINGTON DC', 46)]
# SAN DIEGO CA :  --->   [('SAN DIEGO CA', 100), ('DENVER CO', 48), ('SACRAMENTO CA', 48)]
# SEATTLE WA :  --->   [('SEATTLE WA', 100), ('ATLANTA GA', 50), ('LOS ANGELES CA', 42)]
# SILICON VALLEY :  --->   [('SILICON VALLEY', 100), ('ORANGE COUNTY', 44), ('BOSTON MA', 43)]
# TUCSON AZ :  --->   [('TUCSON AZ', 100), ('PHOENIX AZ', 53), ('NASHVILLE TN', 38)]
# WASHINGTON DC :  --->   [('WASHINGTON DC', 100), ('SACRAMENTO CA', 46), ('AUSTIN TX', 45)]
#
#
# city_df
# -------------------------
# NEW YORK NY :  --->   [('NEW YORK NY', 100), ('ORANGE COUNTY', 42), ('LOS ANGELES CA', 40)]
# CHICAGO IL :  --->   [('CHICAGO IL', 100), ('SAN DIEGO CA', 45), ('WASHINGTON DC', 43)]
# LOS ANGELES CA :  --->   [('LOS ANGELES CA', 100), ('SEATTLE WA', 42), ('NEW YORK NY', 40)]
# MIAMI FL :  --->   [('MIAMI FL', 100), ('BOSTON MA', 35), ('ATLANTA GA', 33)]
# SILICON VALLEY :  --->   [('SILICON VALLEY', 100), ('ORANGE COUNTY', 44), ('DENVER CO', 43)]
# ORANGE COUNTY :  --->   [('ORANGE COUNTY', 100), ('NEW YORK NY', 42), ('SAN DIEGO CA', 40)]
# SAN DIEGO CA :  --->   [('SAN DIEGO CA', 100), ('SAN FRANCISCO CA', 64), ('DENVER CO', 48)]
# PHOENIX AZ :  --->   [('PHOENIX AZ', 100), ('TUCSON AZ', 53), ('SAN DIEGO CA', 36)]
# DALLAS TX :  --->   [('DALLAS TX', 100), ('AUSTIN TX', 56), ('NASHVILLE TN', 48)]
# ATLANTA GA :  --->   [('ATLANTA GA', 100), ('DALLAS TX', 42), ('AUSTIN TX', 42)]
# DENVER CO :  --->   [('DENVER CO', 100), ('SAN DIEGO CA', 38), ('ORANGE COUNTY', 36)]
# AUSTIN TX :  --->   [('AUSTIN TX', 100), ('DALLAS TX', 56), ('NASHVILLE TN', 48)]
# SEATTLE WA :  --->   [('SEATTLE WA', 100), ('ATLANTA GA', 50), ('LOS ANGELES CA', 42)]
# TUCSON AZ :  --->   [('TUCSON AZ', 100), ('PHOENIX AZ', 53), ('SAN FRANCISCO CA', 48)]
# SAN FRANCISCO CA :  --->   [('SAN FRANCISCO CA', 100), ('SAN DIEGO CA', 64), ('SACRAMENTO CA', 48)]
# SACRAMENTO CA :  --->   [('SACRAMENTO CA', 100), ('SAN DIEGO CA', 48), ('WASHINGTON DC', 46)]
# PITTSBURGH PA :  --->   [('PITTSBURGH PA', 100), ('TUCSON AZ', 36), ('PHOENIX AZ', 35)]
# WASHINGTON DC :  --->   [('WASHINGTON DC', 100), ('SACRAMENTO CA', 46), ('AUSTIN TX', 45)]
# NASHVILLE TN :  --->   [('NASHVILLE TN', 100), ('WASHINGTON DC', 48), ('SILICON VALLEY', 38)]
# BOSTON MA :  --->   [('BOSTON MA', 100), ('AUSTIN TX', 44), ('SILICON VALLEY', 43)]

# %% [markdown]
# ### <i>Observations</i>
# <hr />
#
# There are no city entries with erros. All are unique.
#
# <br />

# %% [markdown]
# <br />
# <br />
#
# ### 6. Merge dataframes and drop columns not necessary for analysis
# <hr />

# %% [markdown]
# Now, let us merge all the dataframes together to get a meaningfull master dataframe.

# %%
for df_name, df in dataframes.items():
    print(df_name, "   ---   ", df.shape)
    print('-'*25, "\n")
    print(df.head(), "\n\n")
# Out:
# cab_df    ---    (359392, 7)
# -------------------------
#
#    transaction_id date_of_travel   company        city  km_travelled  \
# 0        10000011     2016-01-08  Pink Cab  ATLANTA GA         30.45
# 1        10000012     2016-01-06  Pink Cab  ATLANTA GA         28.62
# 2        10000013     2016-01-02  Pink Cab  ATLANTA GA          9.04
# 3        10000014     2016-01-07  Pink Cab  ATLANTA GA         33.17
# 4        10000015     2016-01-03  Pink Cab  ATLANTA GA          8.73
#
#    price_charged  cost_of_trip
# 0         370.95       313.635
# 1         358.52       334.854
# 2         125.20        97.632
# 3         377.40       351.602
# 4         114.62        97.776
#
#
# cust_df    ---    (49171, 4)
# -------------------------
#
#    customer_id gender  age  income_usd_per_month
# 0        29290   Male   28                 10813
# 1        27703   Male   27                  9237
# 2        28712   Male   53                 11242
# 3        28020   Male   23                 23327
# 4        27182   Male   33                  8536
#
#
# trans_df    ---    (440098, 3)
# -------------------------
#
#    transaction_id  customer_id payment_mode
# 0        10000011        29290         Card
# 1        10000012        27703         Card
# 2        10000013        28712         Cash
# 3        10000014        28020         Cash
# 4        10000015        27182         Card
#
#
# city_df    ---    (20, 3)
# -------------------------
#
#              city  population   users
# 0     NEW YORK NY     8405837  302149
# 1      CHICAGO IL     1955130  164468
# 2  LOS ANGELES CA     1595037  144132
# 3        MIAMI FL     1339155   17675
# 4  SILICON VALLEY     1177609   27247

# %%
# Merge cab_df and trans_df  on transaction_id
master_df = pd.merge(cab_df, trans_df, on='transaction_id', how='inner')
print(master_df.shape)
master_df.head()
# Out:
# (359392, 9)
#    transaction_id date_of_travel   company        city  km_travelled  \
# 0        10000011     2016-01-08  Pink Cab  ATLANTA GA         30.45
# 1        10000012     2016-01-06  Pink Cab  ATLANTA GA         28.62
# 2        10000013     2016-01-02  Pink Cab  ATLANTA GA          9.04
# 3        10000014     2016-01-07  Pink Cab  ATLANTA GA         33.17
# 4        10000015     2016-01-03  Pink Cab  ATLANTA GA          8.73
#
#    price_charged  cost_of_trip  customer_id payment_mode
# 0         370.95       313.635        29290         Card
# 1         358.52       334.854        27703         Card
# 2         125.20        97.632        28712         Cash
# 3         377.40       351.602        28020         Cash
# 4         114.62        97.776        27182         Card

# %%
# Merge cust_df and master_df on cust_id
master_df = pd.merge(master_df, cust_df, on='customer_id', how='inner')
print(master_df.shape)
master_df.head()
# Out:
# (359392, 12)
#    transaction_id date_of_travel     company        city  km_travelled  \
# 0        10000011     2016-01-08    Pink Cab  ATLANTA GA         30.45
# 1        10351127     2018-07-21  Yellow Cab  ATLANTA GA         26.19
# 2        10412921     2018-11-23  Yellow Cab  ATLANTA GA         42.55
# 3        10000012     2016-01-06    Pink Cab  ATLANTA GA         28.62
# 4        10320494     2018-04-21  Yellow Cab  ATLANTA GA         36.38
#
#    price_charged  cost_of_trip  customer_id payment_mode gender  age  \
# 0         370.95      313.6350        29290         Card   Male   28
# 1         598.70      317.4228        29290         Cash   Male   28
# 2         792.05      597.4020        29290         Card   Male   28
# 3         358.52      334.8540        27703         Card   Male   27
# 4         721.10      467.1192        27703         Card   Male   27
#
#    income_usd_per_month
# 0                 10813
# 1                 10813
# 2                 10813
# 3                  9237
# 4                  9237

# %%
# Merge city_df and master_df on city
master_df = pd.merge(master_df, city_df, on='city', how='inner')
print(master_df.shape)
master_df.head()
# Out:
# (359392, 14)
#    transaction_id date_of_travel     company        city  km_travelled  \
# 0        10000011     2016-01-08    Pink Cab  ATLANTA GA         30.45
# 1        10351127     2018-07-21  Yellow Cab  ATLANTA GA         26.19
# 2        10412921     2018-11-23  Yellow Cab  ATLANTA GA         42.55
# 3        10000012     2016-01-06    Pink Cab  ATLANTA GA         28.62
# 4        10320494     2018-04-21  Yellow Cab  ATLANTA GA         36.38
#
#    price_charged  cost_of_trip  customer_id payment_mode gender  age  \
# 0         370.95      313.6350        29290         Card   Male   28
# 1         598.70      317.4228        29290         Cash   Male   28
# 2         792.05      597.4020        29290         Card   Male   28
# 3         358.52      334.8540        27703         Card   Male   27
# 4         721.10      467.1192        27703         Card   Male   27
#
#    income_usd_per_month  population  users
# 0                 10813      814885  24701
# 1                 10813      814885  24701
# 2                 10813      814885  24701
# 3                  9237      814885  24701
# 4                  9237      814885  24701

# %%
# Check for null values and duplicate entries
print('Percentage of null values in master_df : ', round(master_df.isnull().sum().sum() / master_df.shape[0] * 100, 2), '%')
print('No of duplicate entries in master_df : ', master_df.duplicated().sum(), "\n\n\n")
# Out:
# Percentage of null values in master_df :  0.0 %
# No of duplicate entries in master_df :  0

# %% [markdown]
# Now, let us see if there are any columns that can be dropped

# %%
master_df.head()
# Out:
#    transaction_id date_of_travel     company        city  km_travelled  \
# 0        10000011     2016-01-08    Pink Cab  ATLANTA GA         30.45
# 1        10351127     2018-07-21  Yellow Cab  ATLANTA GA         26.19
# 2        10412921     2018-11-23  Yellow Cab  ATLANTA GA         42.55
# 3        10000012     2016-01-06    Pink Cab  ATLANTA GA         28.62
# 4        10320494     2018-04-21  Yellow Cab  ATLANTA GA         36.38
#
#    price_charged  cost_of_trip  customer_id payment_mode gender  age  \
# 0         370.95      313.6350        29290         Card   Male   28
# 1         598.70      317.4228        29290         Cash   Male   28
# 2         792.05      597.4020        29290         Card   Male   28
# 3         358.52      334.8540        27703         Card   Male   27
# 4         721.10      467.1192        27703         Card   Male   27
#
#    income_usd_per_month  population  users
# 0                 10813      814885  24701
# 1                 10813      814885  24701
# 2                 10813      814885  24701
# 3                  9237      814885  24701
# 4                  9237      814885  24701

# %%
master_df.shape
# Out:
# (359392, 14)

# %%
master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 359392 entries, 0 to 359391
# Data columns (total 14 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   transaction_id        359392 non-null  int64
#  1   date_of_travel        359392 non-null  datetime64[ns]
#  2   company               359392 non-null  object
#  3   city                  359392 non-null  object
#  4   km_travelled          359392 non-null  float64
#  5   price_charged         359392 non-null  float64
#  6   cost_of_trip          359392 non-null  float64
#  7   customer_id           359392 non-null  int64
#  8   payment_mode          359392 non-null  object
#  9   gender                359392 non-null  object
#  10  age                   359392 non-null  int64
#  11  income_usd_per_month  359392 non-null  int64
#  12  population            359392 non-null  int64
#  13  users                 359392 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(6), object(4)
# memory usage: 41.1+ MB

# %%
master_df.describe()
# Out:
#        transaction_id   km_travelled  price_charged   cost_of_trip  \
# count    3.593920e+05  359392.000000  359392.000000  359392.000000
# mean     1.022076e+07      22.567254     423.443311     286.190113
# std      1.268058e+05      12.233526     274.378911     157.993661
# min      1.000001e+07       1.900000      15.600000      19.000000
# 25%      1.011081e+07      12.000000     206.437500     151.200000
# 50%      1.022104e+07      22.440000     386.360000     282.480000
# 75%      1.033094e+07      32.960000     583.660000     413.683200
# max      1.044011e+07      48.000000    2048.030000     691.200000
#
#          customer_id            age  income_usd_per_month    population  \
# count  359392.000000  359392.000000         359392.000000  3.593920e+05
# mean    19191.652115      35.336705          15048.822937  3.132198e+06
# std     21012.412463      12.594234           7969.409482  3.315194e+06
# min         1.000000      18.000000           2000.000000  2.489680e+05
# 25%      2705.000000      25.000000           8424.000000  6.712380e+05
# 50%      7459.000000      33.000000          14685.000000  1.595037e+06
# 75%     36078.000000      42.000000          21035.000000  8.405837e+06
# max     60000.000000      65.000000          35000.000000  8.405837e+06
#
#                users
# count  359392.000000
# mean   158365.582267
# std    100850.051020
# min      3643.000000
# 25%     80021.000000
# 50%    144132.000000
# 75%    302149.000000
# max    302149.000000

# %%
for col in master_df.columns:
    print(col)
    print('-'*25)
    print("No of unique values in {}: {}".format(col, master_df[col].nunique()))
    print("Percentage of unique values in {}: {}%\n".format(col, round(master_df[col].nunique()/master_df.shape[0]*100), 3))
    print(master_df[col].value_counts(), "\n\n")
# Out:
# transaction_id
# -------------------------
# No of unique values in transaction_id: 359392
# Percentage of unique values in transaction_id: 100%
#
# 10000403    1
# 10249510    1
# 10235183    1
# 10233134    1
# 10239277    1
#            ..
# 10273741    1
# 10286027    1
# 10288074    1
# 10281929    1
# 10000365    1
# Name: transaction_id, Length: 359392, dtype: int64
#
#
# date_of_travel
# -------------------------
# No of unique values in date_of_travel: 1095
# Percentage of unique values in date_of_travel: 0%
#
# 2018-01-05    2022
# 2017-12-15    1123
# 2017-12-08    1100
# 2018-12-15    1086
# 2017-11-24    1085
#               ...
# 2016-01-19      88
# 2016-01-12      86
# 2016-01-11      85
# 2016-01-05      47
# 2016-01-04      25
# Name: date_of_travel, Length: 1095, dtype: int64
#
#
# company
# -------------------------
# No of unique values in company: 2
# Percentage of unique values in company: 0%
#
# Yellow Cab    274681
# Pink Cab       84711
# Name: company, dtype: int64
#
#
# city
# -------------------------
# No of unique values in city: 19
# Percentage of unique values in city: 0%
#
# NEW YORK NY       99885
# CHICAGO IL        56625
# LOS ANGELES CA    48033
# WASHINGTON DC     43737
# BOSTON MA         29692
# SAN DIEGO CA      20488
# SILICON VALLEY     8519
# SEATTLE WA         7997
# ATLANTA GA         7557
# DALLAS TX          7017
# MIAMI FL           6454
# AUSTIN TX          4896
# ORANGE COUNTY      3982
# DENVER CO          3825
# NASHVILLE TN       3010
# SACRAMENTO CA      2367
# PHOENIX AZ         2064
# TUCSON AZ          1931
# PITTSBURGH PA      1313
# Name: city, dtype: int64
#
#
# km_travelled
# -------------------------
# No of unique values in km_travelled: 874
# Percentage of unique values in km_travelled: 0%
#
# 33.60    1536
# 24.00    1080
# 22.80    1075
# 35.70    1069
# 16.80    1065
#          ...
# 29.58     308
# 12.24     306
# 3.51      301
# 39.39     300
# 21.84     293
# Name: km_travelled, Length: 874, dtype: int64
#
#
# price_charged
# -------------------------
# No of unique values in price_charged: 99176
# Percentage of unique values in price_charged: 28%
#
# 191.27    18
# 298.32    18
# 198.80    17
# 181.59    17
# 115.53    17
#           ..
# 729.24     1
# 795.23     1
# 953.38     1
# 798.85     1
# 913.23     1
# Name: price_charged, Length: 99176, dtype: int64
#
#
# cost_of_trip
# -------------------------
# No of unique values in cost_of_trip: 16291
# Percentage of unique values in cost_of_trip: 5%
#
# 362.880    186
# 479.808    184
# 471.744    180
# 205.632    178
# 411.264    166
#           ...
# 23.762       1
# 203.965      1
# 21.534       1
# 40.280       1
# 43.844       1
# Name: cost_of_trip, Length: 16291, dtype: int64
#
#
# customer_id
# -------------------------
# No of unique values in customer_id: 46148
# Percentage of unique values in customer_id: 13%
#
# 494      54
# 2939     53
# 2766     51
# 1070     51
# 126      50
#          ..
# 35773     1
# 27809     1
# 17572     1
# 23719     1
# 49043     1
# Name: customer_id, Length: 46148, dtype: int64
#
#
# payment_mode
# -------------------------
# No of unique values in payment_mode: 2
# Percentage of unique values in payment_mode: 0%
#
# Card    215504
# Cash    143888
# Name: payment_mode, dtype: int64
#
#
# gender
# -------------------------
# No of unique values in gender: 2
# Percentage of unique values in gender: 0%
#
# Male      205912
# Female    153480
# Name: gender, dtype: int64
#
#
# age
# -------------------------
# No of unique values in age: 48
# Percentage of unique values in age: 0%
#
# 23    12327
# 20    12229
# 27    12030
# 25    11973
# 32    11959
# 34    11825
# 39    11798
# 22    11796
# 26    11655
# 19    11591
# 40    11536
# 33    11457
# 21    11431
# 30    11165
# 28    11163
# 24    11151
# 37    11086
# 36    11054
# 31    10930
# 38    10906
# 18    10846
# 29    10675
# 35    10555
# 61     4361
# 45     4248
# 49     4158
# 58     4107
# 50     4089
# 47     4087
# 59     4068
# 42     3970
# 51     3931
# 46     3918
# 64     3908
# 41     3852
# 43     3823
# 54     3810
# 52     3784
# 60     3775
# 56     3742
# 63     3733
# 44     3725
# 48     3700
# 53     3641
# 62     3530
# 57     3473
# 55     3442
# 65     3379
# Name: age, dtype: int64
#
#
# income_usd_per_month
# -------------------------
# No of unique values in income_usd_per_month: 22725
# Percentage of unique values in income_usd_per_month: 6%
#
# 20884    134
# 8899     133
# 22525    129
# 16512    121
# 16137    118
#         ...
# 4248       1
# 7834       1
# 34185      1
# 14861      1
# 15695      1
# Name: income_usd_per_month, Length: 22725, dtype: int64
#
#
# population
# -------------------------
# No of unique values in population: 19
# Percentage of unique values in population: 0%
#
# 8405837    99885
# 1955130    56625
# 1595037    48033
# 418859     43737
# 248968     29692
# 959307     20488
# 1177609     8519
# 671238      7997
# 814885      7557
# 942908      7017
# 1339155     6454
# 698371      4896
# 1030185     3982
# 754233      3825
# 327225      3010
# 545776      2367
# 943999      2064
# 631442      1931
# 542085      1313
# Name: population, dtype: int64
#
#
# users
# -------------------------
# No of unique values in users: 19
# Percentage of unique values in users: 0%
#
# 302149    99885
# 164468    56625
# 144132    48033
# 127001    43737
# 80021     29692
# 69995     20488
# 27247      8519
# 25063      7997
# 24701      7557
# 22157      7017
# 17675      6454
# 14978      4896
# 12994      3982
# 12421      3825
# 9270       3010
# 7044       2367
# 6133       2064
# 5712       1931
# 3643       1313
# Name: users, dtype: int64

# %% [markdown]
# ### <i>Observations</i>
# ------------------------------
# 1. <b>transaction_id</b> has 100% unique values. SO we can drop this column.
# 2. <b>customer_id</b> is also a similar id column. But we might need this column because we can segment the dfataframe based on the demographics of users of the cabs.

# %%
# drop transaction_id
print("Before column drop: ", list(master_df.columns), "\n")

master_df.drop(columns='transaction_id', inplace=True)

print("After column drop: ", list(master_df.columns), "\n\n")
# Out:
# Before column drop:  ['transaction_id', 'date_of_travel', 'company', 'city', 'km_travelled', 'price_charged', 'cost_of_trip', 'customer_id', 'payment_mode', 'gender', 'age', 'income_usd_per_month', 'population', 'users']
#
# After column drop:  ['date_of_travel', 'company', 'city', 'km_travelled', 'price_charged', 'cost_of_trip', 'customer_id', 'payment_mode', 'gender', 'age', 'income_usd_per_month', 'population', 'users']

# %% [markdown]
# <br />
# <br />
#
# ### 7. Derive features, if necessary
# <hr />

# %% [markdown]
# Let us take a look at the columns to see if we can dervie some features out of it

# %%
master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 359392 entries, 0 to 359391
# Data columns (total 13 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   date_of_travel        359392 non-null  datetime64[ns]
#  1   company               359392 non-null  object
#  2   city                  359392 non-null  object
#  3   km_travelled          359392 non-null  float64
#  4   price_charged         359392 non-null  float64
#  5   cost_of_trip          359392 non-null  float64
#  6   customer_id           359392 non-null  int64
#  7   payment_mode          359392 non-null  object
#  8   gender                359392 non-null  object
#  9   age                   359392 non-null  int64
#  10  income_usd_per_month  359392 non-null  int64
#  11  population            359392 non-null  int64
#  12  users                 359392 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(5), object(4)
# memory usage: 38.4+ MB

# %%
master_df.head()
# Out:
#   date_of_travel     company        city  km_travelled  price_charged  \
# 0     2016-01-08    Pink Cab  ATLANTA GA         30.45         370.95
# 1     2018-07-21  Yellow Cab  ATLANTA GA         26.19         598.70
# 2     2018-11-23  Yellow Cab  ATLANTA GA         42.55         792.05
# 3     2016-01-06    Pink Cab  ATLANTA GA         28.62         358.52
# 4     2018-04-21  Yellow Cab  ATLANTA GA         36.38         721.10
#
#    cost_of_trip  customer_id payment_mode gender  age  income_usd_per_month  \
# 0      313.6350        29290         Card   Male   28                 10813
# 1      317.4228        29290         Cash   Male   28                 10813
# 2      597.4020        29290         Card   Male   28                 10813
# 3      334.8540        27703         Card   Male   27                  9237
# 4      467.1192        27703         Card   Male   27                  9237
#
#    population  users
# 0      814885  24701
# 1      814885  24701
# 2      814885  24701
# 3      814885  24701
# 4      814885  24701

# %% [markdown]
# ### <i>Observations</i>
# ------------------------------
# 1. We can derive the following columns from date_of_travel:
#     - <b>month_of_travel</b>
#     - <b>day_of_travel</b>
#     - <b>year_of_travel</b>
#     - <b>is_weekend</b>
#     - <b>weekday_of_travel</b>
#
#
# 2. We can also make another feature - age group from the age column

# %%
# derive month_of_travel
master_df['month_of_travel'] = master_df.date_of_travel.dt.month
month_list = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
master_df.month_of_travel = master_df.month_of_travel.apply(lambda m: month_list[m-1])

# derive year_of_travel
master_df['year_of_travel'] = master_df.date_of_travel.dt.year

# dervive day_of_travel
master_df['day_of_travel'] = master_df.date_of_travel.dt.day

# derive weekday_of_travel
master_df['weekday_of_travel'] = master_df.date_of_travel.dt.weekday
weekdays = ['Monday', 'tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
master_df.weekday_of_travel = master_df.weekday_of_travel.apply(lambda d: weekdays[d])

# derive is_weekend - 0(Monday), ..., 4(Friday), 5(Staurday), 6(Sunday)
master_df['is_weekend'] = master_df.weekday_of_travel.apply(lambda day: 'Yes' if day in ['Saturday', 'Sunday'] else 'No')

# Finally drop the date_of_travel column since we have extracted all the features from it
master_df.drop(columns='date_of_travel', inplace=True)

master_df.head()
# Out:
#       company        city  km_travelled  price_charged  cost_of_trip  \
# 0    Pink Cab  ATLANTA GA         30.45         370.95      313.6350
# 1  Yellow Cab  ATLANTA GA         26.19         598.70      317.4228
# 2  Yellow Cab  ATLANTA GA         42.55         792.05      597.4020
# 3    Pink Cab  ATLANTA GA         28.62         358.52      334.8540
# 4  Yellow Cab  ATLANTA GA         36.38         721.10      467.1192
#
#    customer_id payment_mode gender  age  income_usd_per_month  population  \
# 0        29290         Card   Male   28                 10813      814885
# 1        29290         Cash   Male   28                 10813      814885
# 2        29290         Card   Male   28                 10813      814885
# 3        27703         Card   Male   27                  9237      814885
# 4        27703         Card   Male   27                  9237      814885
#
#    users month_of_travel  year_of_travel  day_of_travel weekday_of_travel  \
# 0  24701             Jan            2016              8            Friday
# 1  24701             Jul            2018             21          Saturday
# 2  24701             Nov            2018             23            Friday
# 3  24701             Jan            2016              6         Wednesday
# 4  24701             Apr            2018             21          Saturday
#
#   is_weekend
# 0         No
# 1        Yes
# 2         No
# 3         No
# 4        Yes

# %%
# derive column - age group
master_df['age_group'] = pd.cut( master_df.age, 
                                bins=[0, 15, 19, 29, 39, 49, 59, 200], 
                                labels=['Kid', 'Teenager', '20s', '30s', '40s', '50s', 'Senior Citizen'])

# %%
master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 359392 entries, 0 to 359391
# Data columns (total 18 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   company               359392 non-null  object
#  1   city                  359392 non-null  object
#  2   km_travelled          359392 non-null  float64
#  3   price_charged         359392 non-null  float64
#  4   cost_of_trip          359392 non-null  float64
#  5   customer_id           359392 non-null  int64
#  6   payment_mode          359392 non-null  object
#  7   gender                359392 non-null  object
#  8   age                   359392 non-null  int64
#  9   income_usd_per_month  359392 non-null  int64
#  10  population            359392 non-null  int64
#  11  users                 359392 non-null  int64
#  12  month_of_travel       359392 non-null  object
#  13  year_of_travel        359392 non-null  int64
#  14  day_of_travel         359392 non-null  int64
#  15  weekday_of_travel     359392 non-null  object
#  16  is_weekend            359392 non-null  object
#  17  age_group             359392 non-null  category
# dtypes: category(1), float64(3), int64(7), object(7)
# memory usage: 49.7+ MB

# %%
# unique values in columns in master_df
for col in master_df.columns:
    print(col)
    print('-'*25)
    print("No of unique values in {}: {}".format(col, master_df[col].nunique()))
    print("Percentage of unique values in {}: {}%\n".format(col, round(master_df[col].nunique()/master_df.shape[0]*100), 3))
    print(master_df[col].value_counts(), "\n\n")
# Out:
# company
# -------------------------
# No of unique values in company: 2
# Percentage of unique values in company: 0%
#
# Yellow Cab    274681
# Pink Cab       84711
# Name: company, dtype: int64
#
#
# city
# -------------------------
# No of unique values in city: 19
# Percentage of unique values in city: 0%
#
# NEW YORK NY       99885
# CHICAGO IL        56625
# LOS ANGELES CA    48033
# WASHINGTON DC     43737
# BOSTON MA         29692
# SAN DIEGO CA      20488
# SILICON VALLEY     8519
# SEATTLE WA         7997
# ATLANTA GA         7557
# DALLAS TX          7017
# MIAMI FL           6454
# AUSTIN TX          4896
# ORANGE COUNTY      3982
# DENVER CO          3825
# NASHVILLE TN       3010
# SACRAMENTO CA      2367
# PHOENIX AZ         2064
# TUCSON AZ          1931
# PITTSBURGH PA      1313
# Name: city, dtype: int64
#
#
# km_travelled
# -------------------------
# No of unique values in km_travelled: 874
# Percentage of unique values in km_travelled: 0%
#
# 33.60    1536
# 24.00    1080
# 22.80    1075
# 35.70    1069
# 16.80    1065
#          ...
# 29.58     308
# 12.24     306
# 3.51      301
# 39.39     300
# 21.84     293
# Name: km_travelled, Length: 874, dtype: int64
#
#
# price_charged
# -------------------------
# No of unique values in price_charged: 99176
# Percentage of unique values in price_charged: 28%
#
# 191.27    18
# 298.32    18
# 198.80    17
# 181.59    17
# 115.53    17
#           ..
# 729.24     1
# 795.23     1
# 953.38     1
# 798.85     1
# 913.23     1
# Name: price_charged, Length: 99176, dtype: int64
#
#
# cost_of_trip
# -------------------------
# No of unique values in cost_of_trip: 16291
# Percentage of unique values in cost_of_trip: 5%
#
# 362.880    186
# 479.808    184
# 471.744    180
# 205.632    178
# 411.264    166
#           ...
# 23.762       1
# 203.965      1
# 21.534       1
# 40.280       1
# 43.844       1
# Name: cost_of_trip, Length: 16291, dtype: int64
#
#
# customer_id
# -------------------------
# No of unique values in customer_id: 46148
# Percentage of unique values in customer_id: 13%
#
# 494      54
# 2939     53
# 2766     51
# 1070     51
# 126      50
#          ..
# 35773     1
# 27809     1
# 17572     1
# 23719     1
# 49043     1
# Name: customer_id, Length: 46148, dtype: int64
#
#
# payment_mode
# -------------------------
# No of unique values in payment_mode: 2
# Percentage of unique values in payment_mode: 0%
#
# Card    215504
# Cash    143888
# Name: payment_mode, dtype: int64
#
#
# gender
# -------------------------
# No of unique values in gender: 2
# Percentage of unique values in gender: 0%
#
# Male      205912
# Female    153480
# Name: gender, dtype: int64
#
#
# age
# -------------------------
# No of unique values in age: 48
# Percentage of unique values in age: 0%
#
# 23    12327
# 20    12229
# 27    12030
# 25    11973
# 32    11959
# 34    11825
# 39    11798
# 22    11796
# 26    11655
# 19    11591
# 40    11536
# 33    11457
# 21    11431
# 30    11165
# 28    11163
# 24    11151
# 37    11086
# 36    11054
# 31    10930
# 38    10906
# 18    10846
# 29    10675
# 35    10555
# 61     4361
# 45     4248
# 49     4158
# 58     4107
# 50     4089
# 47     4087
# 59     4068
# 42     3970
# 51     3931
# 46     3918
# 64     3908
# 41     3852
# 43     3823
# 54     3810
# 52     3784
# 60     3775
# 56     3742
# 63     3733
# 44     3725
# 48     3700
# 53     3641
# 62     3530
# 57     3473
# 55     3442
# 65     3379
# Name: age, dtype: int64
#
#
# income_usd_per_month
# -------------------------
# No of unique values in income_usd_per_month: 22725
# Percentage of unique values in income_usd_per_month: 6%
#
# 20884    134
# 8899     133
# 22525    129
# 16512    121
# 16137    118
#         ...
# 4248       1
# 7834       1
# 34185      1
# 14861      1
# 15695      1
# Name: income_usd_per_month, Length: 22725, dtype: int64
#
#
# population
# -------------------------
# No of unique values in population: 19
# Percentage of unique values in population: 0%
#
# 8405837    99885
# 1955130    56625
# 1595037    48033
# 418859     43737
# 248968     29692
# 959307     20488
# 1177609     8519
# 671238      7997
# 814885      7557
# 942908      7017
# 1339155     6454
# 698371      4896
# 1030185     3982
# 754233      3825
# 327225      3010
# 545776      2367
# 943999      2064
# 631442      1931
# 542085      1313
# Name: population, dtype: int64
#
#
# users
# -------------------------
# No of unique values in users: 19
# Percentage of unique values in users: 0%
#
# 302149    99885
# 164468    56625
# 144132    48033
# 127001    43737
# 80021     29692
# 69995     20488
# 27247      8519
# 25063      7997
# 24701      7557
# 22157      7017
# 17675      6454
# 14978      4896
# 12994      3982
# 12421      3825
# 9270       3010
# 7044       2367
# 6133       2064
# 5712       1931
# 3643       1313
# Name: users, dtype: int64
#
#
# month_of_travel
# -------------------------
# No of unique values in month_of_travel: 12
# Percentage of unique values in month_of_travel: 0%
#
# Dec    47007
# Nov    42700
# Oct    40852
# Sep    36859
# Aug    31323
# Jul    27676
# Jun    24713
# May    23701
# Jan    23174
# Mar    21646
# Apr    21434
# Feb    18307
# Name: month_of_travel, dtype: int64
#
#
# year_of_travel
# -------------------------
# No of unique values in year_of_travel: 3
# Percentage of unique values in year_of_travel: 0%
#
# 2017    128510
# 2018    123563
# 2016    107319
# Name: year_of_travel, dtype: int64
#
#
# day_of_travel
# -------------------------
# No of unique values in day_of_travel: 31
# Percentage of unique values in day_of_travel: 0%
#
# 17    13421
# 3     13327
# 24    13311
# 10    13255
# 5     12803
# 6     12428
# 8     12407
# 15    12211
# 22    12081
# 1     11954
# 20    11935
# 7     11918
# 29    11688
# 9     11659
# 27    11630
# 13    11576
# 23    11561
# 16    11552
# 21    11416
# 14    11405
# 2     11366
# 19    11318
# 28    11220
# 26    11099
# 12    11067
# 30    10908
# 4     10882
# 18    10431
# 11    10361
# 25    10312
# 31     6890
# Name: day_of_travel, dtype: int64
#
#
# weekday_of_travel
# -------------------------
# No of unique values in weekday_of_travel: 7
# Percentage of unique values in weekday_of_travel: 0%
#
# Friday       81402
# Saturday     78234
# Sunday       70310
# Thursday     39747
# Wednesday    30102
# tuesday      29860
# Monday       29737
# Name: weekday_of_travel, dtype: int64
#
#
# is_weekend
# -------------------------
# No of unique values in is_weekend: 2
# Percentage of unique values in is_weekend: 0%
#
# No     210848
# Yes    148544
# Name: is_weekend, dtype: int64
#
#
# age_group
# -------------------------
# No of unique values in age_group: 6
# Percentage of unique values in age_group: 0%
#
# 20s               116430
# 30s               112735
# 40s                47017
# 50s                38087
# Senior Citizen     22686
# Teenager           22437
# Kid                    0
# Name: age_group, dtype: int64

# %% [markdown]
# <br />
# <br />
#
# ### 8. Check for outliers
# <hr />

# %%
master_df.describe()
# Out:
#         km_travelled  price_charged   cost_of_trip    customer_id  \
# count  359392.000000  359392.000000  359392.000000  359392.000000
# mean       22.567254     423.443311     286.190113   19191.652115
# std        12.233526     274.378911     157.993661   21012.412463
# min         1.900000      15.600000      19.000000       1.000000
# 25%        12.000000     206.437500     151.200000    2705.000000
# 50%        22.440000     386.360000     282.480000    7459.000000
# 75%        32.960000     583.660000     413.683200   36078.000000
# max        48.000000    2048.030000     691.200000   60000.000000
#
#                  age  income_usd_per_month    population          users  \
# count  359392.000000         359392.000000  3.593920e+05  359392.000000
# mean       35.336705          15048.822937  3.132198e+06  158365.582267
# std        12.594234           7969.409482  3.315194e+06  100850.051020
# min        18.000000           2000.000000  2.489680e+05    3643.000000
# 25%        25.000000           8424.000000  6.712380e+05   80021.000000
# 50%        33.000000          14685.000000  1.595037e+06  144132.000000
# 75%        42.000000          21035.000000  8.405837e+06  302149.000000
# max        65.000000          35000.000000  8.405837e+06  302149.000000
#
#        year_of_travel  day_of_travel
# count   359392.000000  359392.000000
# mean      2017.045199      15.628447
# std          0.800239       8.827151
# min       2016.000000       1.000000
# 25%       2016.000000       8.000000
# 50%       2017.000000      16.000000
# 75%       2018.000000      23.000000
# max       2018.000000      31.000000

# %% [markdown]
# Let us check for outliers by plotting box plots for each of the numerical columns

# %%
sns.set_style('darkgrid')

# %%
fig, ax = plt.subplots(4,3, figsize=(20,20))

# select numeric columns only
numeric_cols = list(master_df.select_dtypes(include=np.number).columns)

# set title for subplots
fig.suptitle("Box plots for numeric columns to find outliers", fontsize=30)


for i, col in enumerate(numeric_cols):
    r = i // 3
    c = i % 3
    sns.boxplot(master_df[col], ax=ax[r][c])
    ax[r,c].set_title(col, fontsize=15)
    
ax[3,1].set_axis_off()
ax[3,2].set_axis_off()

# %% [markdown]
# ### <i>Observations</i>
# ------------------------------
# The only column that seems to have outliers is <b>price_charged</b>. Let us take a look at the same. Moreover, this column seems to be dependent on the <b>cost_of_trip</b> column, which on the other hand has no outliers.

# %%
# check whether hypothesis that price_changed and cost_of_trip is correlated by plotting a heatmap
plt.figure(figsize=(10, 10))
sns.heatmap(master_df.corr(), cmap='Blues', annot=True, linewidth=0.5, fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### <i>Observations</i>
# ------------------------------
# Dark colour signifies high correlation(->1) and light colour signifies low correlation(->0).
#
# For <b>price_changed</b> and <b>cost_of_trip</b> the correlation colour is dark blue, which corresponds to a correlation of ~0.86 (86%). This is a very high value. The same trend can be seen with <b>km_travelled</b>.
#
# Now, let us closely inspect the <b>price_charged</b> column to try find the reason behind the outliers.
# <br />

# %%
master_df[['km_travelled', 'price_charged', 'cost_of_trip']]
# Out:
#         km_travelled  price_charged  cost_of_trip
# 0              30.45         370.95      313.6350
# 1              26.19         598.70      317.4228
# 2              42.55         792.05      597.4020
# 3              28.62         358.52      334.8540
# 4              36.38         721.10      467.1192
# ...              ...            ...           ...
# 359387         38.40         668.93      525.3120
# 359388          3.57          67.60       44.5536
# 359389         23.46         331.97      337.8240
# 359390         27.60         358.23      364.3200
# 359391         34.24         453.11      427.3152
#
# [359392 rows x 3 columns]

# %%
master_df[['km_travelled', 'price_charged', 'cost_of_trip']].describe()
# Out:
#         km_travelled  price_charged   cost_of_trip
# count  359392.000000  359392.000000  359392.000000
# mean       22.567254     423.443311     286.190113
# std        12.233526     274.378911     157.993661
# min         1.900000      15.600000      19.000000
# 25%        12.000000     206.437500     151.200000
# 50%        22.440000     386.360000     282.480000
# 75%        32.960000     583.660000     413.683200
# max        48.000000    2048.030000     691.200000

# %% [markdown]
# ### <i>Observations</i>
# ------------------------------
# As you can see the 75th percentile of <b>km_travelled</b>, <price_charged</b> and <b>cost_of_trip</b> are approx. 33, 584 and 414 respectively. This goes with the 25th and 50th percentiles. On the other hand, the maximum value in these columns are 48, 2048, 691 respectively. While <b>klm_travelled</b> and <b>cost_of_trip</b> values seem to be reasonable, there is a huge jump in the value of <b>price charged</b>.
#
# Let us take a closer look at these hyped values in the <b>price_charged</b> column.
#
# <br />

# %%
fig, ax = plt.subplots(1, 3, figsize=(15,5))
sns.boxplot(y=master_df.km_travelled, orient='v', ax=ax[0])
sns.boxplot(y=master_df.price_charged, orient='v', ax=ax[1])
sns.boxplot(y=master_df.cost_of_trip, orient='v', ax=ax[2])
# Out:
# <AxesSubplot:ylabel='cost_of_trip'>

# %%
fig, ax = plt.subplots(1, 3, figsize=(15,5))
sns.distplot(master_df.km_travelled, bins=50, ax=ax[0])
sns.distplot(master_df.price_charged, bins=50, ax=ax[1])
sns.distplot(master_df.cost_of_trip, bins=50, ax=ax[2])
# Out:
# <AxesSubplot:xlabel='cost_of_trip', ylabel='Density'>

# %%
fig, ax = plt.subplots(1, 3, figsize=(15,5))
sns.scatterplot(master_df.km_travelled, master_df.price_charged, ax=ax[0])
sns.scatterplot(master_df.cost_of_trip, master_df.price_charged, ax=ax[1])
sns.scatterplot(master_df.km_travelled, master_df.cost_of_trip, ax=ax[2])
# Out:
# <AxesSubplot:xlabel='km_travelled', ylabel='cost_of_trip'>

# %% [markdown]
# ### <i>Observations</i>
# <hr />
#
# As you can see, the distribution of <b>km_travelled</b> and <b>cost_of_trip</b> are some what resemble and can almost be approximated to a trapezoid with 2 right angles.
#
# While that of <b>price_charged</b> is quite different. It follows the same trend as the other two for <b>price_charged < 500</b>. After that the slope is dropping at a faster rate towards large values.
#
# <br />

# %%
# look at rows with oitliers in price_charged column
q1 = np.percentile(master_df.price_charged, 25, interpolation='midpoint')
q3 = np.percentile(master_df.price_charged, 75, interpolation='midpoint')

IQR = q3 - q1

print(q1, q3, IQR)
# Out:
# 206.435 583.66 377.22499999999997

# %%
upper = q3 + 1.5*IQR
lower = q1 - 1.5*IQR

print(upper, lower)
# Out:
# 1149.4975 -359.4025

# %%
outlier_df = master_df[(master_df.price_charged >= upper) | (master_df.price_charged <= lower)] \
                        [['km_travelled', 'price_charged', 'cost_of_trip']]
outlier_df.shape
# Out:
# (5958, 3)

# %%
outlier_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5958 entries, 24 to 354039
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   km_travelled   5958 non-null   float64
#  1   price_charged  5958 non-null   float64
#  2   cost_of_trip   5958 non-null   float64
# dtypes: float64(3)
# memory usage: 186.2 KB

# %%
outlier_df.head()
# Out:
#     km_travelled  price_charged  cost_of_trip
# 24         33.93        1341.17      464.1624
# 28         42.18        1412.06      516.2832
# 41         46.02        1540.61      596.4192
# 49         38.08        1239.72      539.2128
# 71         38.85        1430.64      545.4540

# %%
print("Percentage of outliers in price_charged: {}%\n\n".format(round(outlier_df.shape[0] / master_df.shape[0] * 100, 2)))
# Out:
# Percentage of outliers in price_charged: 1.66%

# %% [markdown]
# <br />
# <br />
#
# ### 9. Sanity checks
# <hr />

# %%
master_df.describe()
# Out:
#         km_travelled  price_charged   cost_of_trip    customer_id  \
# count  359392.000000  359392.000000  359392.000000  359392.000000
# mean       22.567254     423.443311     286.190113   19191.652115
# std        12.233526     274.378911     157.993661   21012.412463
# min         1.900000      15.600000      19.000000       1.000000
# 25%        12.000000     206.437500     151.200000    2705.000000
# 50%        22.440000     386.360000     282.480000    7459.000000
# 75%        32.960000     583.660000     413.683200   36078.000000
# max        48.000000    2048.030000     691.200000   60000.000000
#
#                  age  income_usd_per_month    population          users  \
# count  359392.000000         359392.000000  3.593920e+05  359392.000000
# mean       35.336705          15048.822937  3.132198e+06  158365.582267
# std        12.594234           7969.409482  3.315194e+06  100850.051020
# min        18.000000           2000.000000  2.489680e+05    3643.000000
# 25%        25.000000           8424.000000  6.712380e+05   80021.000000
# 50%        33.000000          14685.000000  1.595037e+06  144132.000000
# 75%        42.000000          21035.000000  8.405837e+06  302149.000000
# max        65.000000          35000.000000  8.405837e+06  302149.000000
#
#        year_of_travel  day_of_travel
# count   359392.000000  359392.000000
# mean      2017.045199      15.628447
# std          0.800239       8.827151
# min       2016.000000       1.000000
# 25%       2016.000000       8.000000
# 50%       2017.000000      16.000000
# 75%       2018.000000      23.000000
# max       2018.000000      31.000000

# %% [markdown]
# <br />

# %% [markdown]
# <br />
# <br />
# <br />
#
#
# ## Exploratory Data Analysis
# <hr />
#
# 1. Univariate analysis
# 2. Bivariate analysis
# 3. Multivariate analysis
# <br />
# <br />
#
# ### Univariate analysis
# <hr />

# %%
master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 359392 entries, 0 to 359391
# Data columns (total 18 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   company               359392 non-null  object
#  1   city                  359392 non-null  object
#  2   km_travelled          359392 non-null  float64
#  3   price_charged         359392 non-null  float64
#  4   cost_of_trip          359392 non-null  float64
#  5   customer_id           359392 non-null  int64
#  6   payment_mode          359392 non-null  object
#  7   gender                359392 non-null  object
#  8   age                   359392 non-null  int64
#  9   income_usd_per_month  359392 non-null  int64
#  10  population            359392 non-null  int64
#  11  users                 359392 non-null  int64
#  12  month_of_travel       359392 non-null  object
#  13  year_of_travel        359392 non-null  int64
#  14  day_of_travel         359392 non-null  int64
#  15  weekday_of_travel     359392 non-null  object
#  16  is_weekend            359392 non-null  object
#  17  age_group             359392 non-null  category
# dtypes: category(1), float64(3), int64(7), object(7)
# memory usage: 49.7+ MB

# %%
master_df.head(3)
# Out:
#       company        city  km_travelled  price_charged  cost_of_trip  \
# 0    Pink Cab  ATLANTA GA         30.45         370.95      313.6350
# 1  Yellow Cab  ATLANTA GA         26.19         598.70      317.4228
# 2  Yellow Cab  ATLANTA GA         42.55         792.05      597.4020
#
#    customer_id payment_mode gender  age  income_usd_per_month  population  \
# 0        29290         Card   Male   28                 10813      814885
# 1        29290         Cash   Male   28                 10813      814885
# 2        29290         Card   Male   28                 10813      814885
#
#    users month_of_travel  year_of_travel  day_of_travel weekday_of_travel  \
# 0  24701             Jan            2016              8            Friday
# 1  24701             Jul            2018             21          Saturday
# 2  24701             Nov            2018             23            Friday
#
#   is_weekend age_group
# 0         No       20s
# 1        Yes       20s
# 2         No       20s

# %%
numeric_cols = ['km_travelled', 'price_charged', 'cost_of_trip', 'income_usd_per_month', 'population', 'users']
category_cols = ['company', 'city', 'payment_mode', 'gender', 'age', 'age_group']
date_cols = ['month_of_travel', 'year_of_travel', 'day_of_travel', 'weekday_of_travel', 'is_weekend']

# %%
# Analyse the numerical columns
for col in numeric_cols:
    plt.figure(figsize=(10,5))
    sns.histplot(master_df[col])
    plt.xlabel(col, fontsize=15)
    plt.show()

# %% [markdown]
# <br />

# %%
# Analyse the categorical columns
for col in category_cols:
    plt.figure(figsize=(15,5))
    order_of_values = master_df[col].value_counts().index
    sns.countplot(master_df[col], order=order_of_values)
    plt.xlabel(col, fontsize=15)
    plt.xticks(label=order_of_values, fontsize=12, rotation='vertical' if col=='city' else 'horizontal')
    plt.show()

# %% [markdown]
# <br />

# %%
# Analyse the date columns
for col in date_cols:
    plt.figure(figsize=(15,5))
    order_of_values = master_df[col].value_counts().index
    sns.countplot(master_df[col], order=order_of_values)
    plt.xlabel(col, fontsize=15)
    plt.xticks(label=order_of_values, fontsize=12)
    plt.show()

# %% [markdown]
# <br />

# %%
fig, ax = plt.subplots(4,3, figsize=(20,20))

# select numeric columns only
for i, col in enumerate(list(master_df.select_dtypes(include=np.number).columns)):
    r = i // 3
    c = i % 3
    sns.boxplot(master_df[col], ax=ax[r][c])
    ax[r,c].set_title(col, fontsize=15)
    
ax[3,1].set_axis_off()
ax[3,2].set_axis_off()

# %% [markdown]
# <br />
#
# ### Observations
# <ol>
#     <li> There is more data pertaining to yellow cab </li>
#     <li> More no of cab users are from Newyork (almost double the no of the runner city), followed by Chicago, WashingtonDC and Ls Angeles </li>
#     <li> More payment has been made on card than cash </li>
#     <li> More male cab users than female </li>
#     <li> Most no of cab users fall in the age groups of 20-40 </li>
# </ol>
#
# <br />
# <br />

# %% [markdown]
# ### Segmented univariate analysis
# <hr />
#
# Let us analyse the data by segmenting based on the company, Yellow cab and Pink cab.
# <br />

# %%
fig, ax = plt.subplots(2,3, figsize=(20,15))

# select numeric columns only
for i, col in enumerate(numeric_cols):
    r = i // 3
    c = i % 3
    sns.boxplot(x='company', y=col, data=master_df, ax=ax[r][c])
    ax[r,c].set_title(col, fontsize=15)

# %% [markdown]
# <br />

# %%
# Analyse the categorical columns
for col in category_cols:
    plt.figure(figsize=(15,5))
    order_of_values = master_df[col].value_counts().index
    sns.countplot(x=col, hue='company', data=master_df, order=order_of_values)
    plt.xlabel(col, fontsize=15)
    plt.ylabel('count', fontsize=15)
    plt.xticks(label=order_of_values, fontsize=12, rotation='vertical' if col=='city' else 'horizontal')
    plt.show()

# %% [markdown]
# <br />

# %%
# Analyse the date columns
for col in date_cols:
    plt.figure(figsize=(15,5))
    order_of_values = master_df[col].value_counts().index
    sns.countplot(x=col, hue='company', data=master_df, order=order_of_values)
    plt.xlabel(col, fontsize=15)
    plt.ylabel('count', fontsize=15)
    plt.xticks(label=order_of_values, fontsize=12, rotation='vertical' if col=='city' else 'horizontal')
    plt.show()

# %% [markdown]
# <br />
#
# ### Observations
# <hr />
# <ol>
#     <li> The km_travelled is comparable for both Yellow and Pink cab </li>
#     <li> Both price_charged and cost_of_trip is comparatively higher for Yellow cab than Pink cab </li>
#     <li> In all the cities where the no of users is high, more no of poeple have opted for Yellow cab, especially in Neywork where this amount is almost 4 times that for Pink cab </li>
#     <li> All age groups have shown more interest in Yellow cab than pink cab </li>
#     <li> There is more demand for cabs (here also Yellow cab is in favour) during the last months of the year (highest in december) and low during the first months of the year (lowest in february). </li>
#     <li> More people have been found to using cab on Fridays, Saturdays and Sundays .i.e., when the weekend starts and during the weekend. </li>
# </ol>
#
# <br />
# <br />

# %% [markdown]
# <br />
# <br />
#
# ### Bivariate analysis
# <hr />

# %%
master_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 359392 entries, 0 to 359391
# Data columns (total 18 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   company               359392 non-null  object
#  1   city                  359392 non-null  object
#  2   km_travelled          359392 non-null  float64
#  3   price_charged         359392 non-null  float64
#  4   cost_of_trip          359392 non-null  float64
#  5   customer_id           359392 non-null  int64
#  6   payment_mode          359392 non-null  object
#  7   gender                359392 non-null  object
#  8   age                   359392 non-null  int64
#  9   income_usd_per_month  359392 non-null  int64
#  10  population            359392 non-null  int64
#  11  users                 359392 non-null  int64
#  12  month_of_travel       359392 non-null  object
#  13  year_of_travel        359392 non-null  int64
#  14  day_of_travel         359392 non-null  int64
#  15  weekday_of_travel     359392 non-null  object
#  16  is_weekend            359392 non-null  object
#  17  age_group             359392 non-null  category
# dtypes: category(1), float64(3), int64(7), object(7)
# memory usage: 57.8+ MB

# %%
fig, ax = plt.subplots(2,3, figsize=(20,10))

# select numeric columns only
for i, col in enumerate(numeric_cols):
    r = i // 3
    c = i % 3
    sns.boxplot(x='company', y=col, data=master_df, ax=ax[r][c])
    ax[r,c].set_title(col, fontsize=15)

# %%
df = master_df.pivot_table(index='company', columns='month_of_travel', values='income_usd_per_month', aggfunc='sum')
df
# Out:
# month_of_travel        Apr        Aug        Dec        Feb        Jan  \
# company
# Pink Cab          60852931  117091807  173442655   51371254   75192262
# Yellow Cab       260061837  355159647  532437186  225076755  273518561
#
# month_of_travel        Jul        Jun        Mar        May        Nov  \
# company
# Pink Cab          98502423   88324971   64084544   75744487  165824473
# Yellow Cab       315099565  282807329  262873988  280596458  478468777
#
# month_of_travel        Oct        Sep
# company
# Pink Cab         159517246  145717889
# Yellow Cab       456509833  410149695

# %%
order_of_values = df.sum().sort_values(ascending=False).index
order_of_values
# Out:
# Index(['Dec', 'Nov', 'Oct', 'Sep', 'Aug', 'Jul', 'Jun', 'May', 'Jan', 'Mar',
#        'Apr', 'Feb'],
#       dtype='object', name='month_of_travel')

# %%
df.T.plot(kind='bar', ylabel='income_usd_per_month', figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='month_of_travel', ylabel='income_usd_per_month'>

# %% [markdown]
# <br />

# %% [markdown]
# <br />
# <br />
#
# ### Multivariate analysis
# <hr />

# %%
# Pair plot
plt.figure(figsize=(20, 20))
sns.pairplot(master_df)

# %% [markdown]
# <br />
#
# ### Inference
# <hr />
# It is best to invest in <b>Yellow Cab</b>.
#
# The reasons for the same are:
# - More income per month
# - More users
# - Comparatively higher cost of trip and price charged, but not too high for users to look in for alternatives.
#
# <br />
# <br />
